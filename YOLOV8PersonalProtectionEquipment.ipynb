# %%
# !nvidia-smi

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=predict model="/content/runs/detect/train/weights/best.pt" conf=0.25 source="/content/drive/MyDrive/Datasets/ConstructionSiteSafety/test/images/003357_jpg.rf.9867f91e88089bb68dc95947d5116d14.jpg"

# %% [markdown]
# Custom Data training

# %%
# !yolo task=detect mode=train model=yolov8l.pt conf=0.25 data="/content/drive/MyDrive/Datasets/ConstructionSiteSafety/data.yaml" epochs=70 imgsz=640
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 246MB/s]
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
